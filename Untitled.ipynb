# %%
# !pip install ultralytics --user
# Out:
# ...
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: C:\Users\ADMIN\anaconda3\python.exe -m pip install --upgrade pip

# %%
from ultralytics import YOLO

model = YOLO("model/detection_best.pt")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\ultralytics\nn\tasks.py:1209, in torch_safe_load(weight, safe_only)
#    1208         else:
# -> 1209             ckpt = torch.load(file, map_location="cpu")
#    1211 except ModuleNotFoundError as e:  # e.name is missing module name
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ultralytics\utils\patches.py:107, in torch_load(*args, **kwargs)
#     105     kwargs["weights_only"] = False
# --> 107 return _torch_load(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\serialization.py:1471, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1470                 raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
# -> 1471         return _load(
#    1472             opened_zipfile,
# ...

# %%
# !pip install yolov5
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/953.5 kB ? eta -:--:--
#    --------------------------------------- 953.5/953.5 kB 11.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    -- ------------------------------------- 2.4/38.8 MB 12.2 MB/s eta 0:00:03
#    ----- ---------------------------------- 5.0/38.8 MB 11.6 MB/s eta 0:00:03
#    ------- -------------------------------- 7.6/38.8 MB 11.7 MB/s eta 0:00:03
#    ---------- ----------------------------- 10.0/38.8 MB 11.9 MB/s eta 0:00:03
#    ------------ --------------------------- 12.3/38.8 MB 11.9 MB/s eta 0:00:03
#    --------------- ------------------------ 14.7/38.8 MB 11.8 MB/s eta 0:00:03
#    ----------------- ---------------------- 17.3/38.8 MB 11.9 MB/s eta 0:00:02
#    -------------------- ------------------- 19.7/38.8 MB 11.8 MB/s eta 0:00:02
# ...

# %%
# !pip uninstall ultralytics
